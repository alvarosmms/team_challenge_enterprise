# %% [markdown]
# ![Logo](/Users/alvarosanchez/ONLINE_DS_THEBRIDGE_ALVAROSMMS-1/team_challenge_enterprise/Sprint_10/banner.jpg)

# %%
import pandas as pd
from toolbox_ML import describe_df, tipifica_variables, get_features_num_regression, plot_features_num_regression, get_features_cat_regression, plot_features_cat_regression

# %%
df = pd.read_csv("/Users/alvarosanchez/ONLINE_DS_THEBRIDGE_ALVAROSMMS-1/ONLINE_DS_THEBRIDGE_ALVAROSMMS/Sprint_10/Unidad_2/Team Challenge/data/titanic.csv")

# %% [markdown]
# ### Funcion: describe_df

# %%
describe_df(df)
# Out:
# Column        survived pclass     sex      age  sibsp  parch     fare  \
# Data_Type        int64  int64  object  float64  int64  int64  float64
# Null (%)           0.0    0.0     0.0    19.87    0.0    0.0      0.0
# Unique_Values        2      3       2       88      7      7      248
# Cardin (%)        0.22   0.34    0.22     9.88   0.79   0.79    27.83
#
# Column        embarked   class     who adult_male    deck embark_town   alive  \
# Data_Type       object  object  object       bool  object      object  object
# Null (%)          0.22     0.0     0.0        0.0   77.22        0.22     0.0
# Unique_Values        3       3       3          2       7           3       2
# Cardin (%)        0.34    0.34    0.34       0.22    0.79        0.34    0.22
#
# Column        alone
# Data_Type      bool
# Null (%)        0.0
# Unique_Values     2
# Cardin (%)     0.22

# %% [markdown]
# ### Funcion: tipifica_variables

# %%
tipifica_variables(df, 2 , 0.5)
# Out:
#                      tipo_sugerido
# nombre_variable
# survived                   Binaria
# pclass           Numérica Discreta
# sex                        Binaria
# age              Numérica Discreta
# sibsp            Numérica Discreta
# parch            Numérica Discreta
# fare             Numérica Discreta
# embarked         Numérica Discreta
# class            Numérica Discreta
# who              Numérica Discreta
# adult_male                 Binaria
# deck             Numérica Discreta
# embark_town      Numérica Discreta
# alive                      Binaria
# alone                      Binaria

# %% [markdown]
# ### Funcion: get_features_num_regression

# %%
titanic_cleaned = df.copy()
titanic_cleaned = titanic_cleaned.dropna(subset=["age", "fare", "survived"])  # Eliminamos filas con NaN en estas columnas


features_num = get_features_num_regression(titanic_cleaned, target_col="age", umbral_corr=0.1)
features_num
# Out:
# ✅ Columnas seleccionadas: ['pclass', 'sibsp', 'parch']
# ['pclass', 'sibsp', 'parch']

# %% [markdown]
# ### Funcion: plot_features_num_regression

# %%
plot_features_num_regression(titanic_cleaned, target_col="age", columns=features_num, umbral_corr=0.1)
# Out:
# ✅ Columnas seleccionadas para pairplot: ['pclass', 'sibsp', 'parch']
# ['pclass', 'sibsp', 'parch']

# %% [markdown]
# ### Funcion: get_features_cat_regression

# %%
features_cat = get_features_cat_regression(titanic_cleaned, target_col="age", pvalue=0.05)
features_cat
# Out:
# ✅ Columnas seleccionadas: ['embarked', 'class', 'who', 'embark_town']
# ['embarked', 'class', 'who', 'embark_town']

# %% [markdown]
# ### Funcion: plot_features_cat_regression

# %%
plot_features_cat_regression(titanic_cleaned, target_col="age", columns=features_cat, pvalue=0.05, with_individual_plot=True)
# Out:
# ✅ Columnas seleccionadas: ['embarked', 'class', 'who', 'embark_town']
# ['embarked', 'class', 'who', 'embark_town']
